# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# %run ../Modules/Importing.py

# %%
sns.set(style='whitegrid',font_scale = 1.5)

# %%
file = '/Users/ballanr/Desktop/File Outputs/DR15/1&2 List.csv'
ones,twos,threes,fours,others = f.Br20_Confidence(file,0,1);

# %%
variable = ones
data1 = pd.DataFrame(columns = ['Br11 EqW','Br20 Confidence','Br11 Confidence','Br20 EqW'])
br11 = []
br11confidence = []
br20confidence = []
br20eqw = []
for i in range(len(variable)):
    br11.append(variable[i][0])
    br11confidence.append(variable[i][1])
    br20confidence.append(variable[i][2])
    br20eqw.append(variable[i][3])
br11 = np.asarray(br11)
br20confidence = np.asarray(br20confidence)
br11confidence = np.asarray(br11confidence)
br20eqw = np.asarray(br20eqw)
data1['Br11 EqW'] = br11
data1['Br20 Confidence'] = br20confidence
data1['Confidence'] = br11confidence
data1['Br20 EqW'] = br20eqw

# %% [markdown]
# ## Br20 Confidence vs. Br20 EqW

# %%
p = sns.JointGrid(y='Br20 Confidence',x='Br20 EqW', data=data1, size=10);

p = p.plot_joint(plt.scatter,s=5,color='black');
plt.xlim(-5,5)
p = p.plot_joint(sns.kdeplot,shade=True,shade_lowest=False,cmap='RdGy',zorder=0,n_levels=15)

p = p.plot_marginals(sns.distplot,kde=True)

plt.suptitle('Ones')

# %%
plt.figure(figsize=(13,10))
sns.distplot(br20confidence,bins=20,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'blue','alpha':.7})
plt.xlabel('Fmax/Continuum Error')
plt.title('Ones')

# %%
p = sns.JointGrid(y='Br20 Confidence',x='Br20 EqW', data=data1, size=10);

p = p.plot_joint(plt.scatter,s=5,color='black');
#plt.xlim(-5,5)
p = p.plot_joint(sns.kdeplot,shade=True,shade_lowest=False,cmap='RdGy',zorder=0,n_levels=15)

p = p.plot_marginals(sns.distplot,kde=True)

plt.suptitle('Twos')

# %%
plt.figure(figsize=(13,10))
sns.distplot(br20confidence,bins=20,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'blue','alpha':.7})
plt.xlabel('Fmax/Continuum Error')
plt.title('Twos')

# %%
p = sns.JointGrid(y='Br20 Confidence',x='Br20 EqW', data=data1, size=10);

p = p.plot_joint(plt.scatter,s=5,color='black');
plt.xlim(-2.5,7.5)
p = p.plot_joint(sns.kdeplot,shade=True,shade_lowest=False,cmap='RdGy',zorder=0,n_levels=15)

p = p.plot_marginals(sns.distplot,kde=True)

plt.suptitle('Threes')

# %%
plt.figure(figsize=(13,10))
sns.distplot(br20confidence,bins=20,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'blue','alpha':.7})
plt.xlabel('Fmax/Continuum Error')
plt.title('Threes')

# %%
p = sns.JointGrid(y='Br20 Confidence',x='Br20 EqW', data=data1, size=10);

p = p.plot_joint(plt.scatter,s=5,color='black');

p = p.plot_joint(sns.kdeplot,shade=True,shade_lowest=False,cmap='RdGy',zorder=0,n_levels=15)

p = p.plot_marginals(sns.distplot,kde=True)
plt.suptitle('Fours')

# %%
plt.figure(figsize=(13,10))
sns.distplot(br20confidence,bins=20,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'blue','alpha':.7})
plt.xlabel('Fmax/Continuum Error')
plt.title('Fours')

# %% [markdown]
# ## Br20 EqW vs. Br11 EqW

# %%
p = sns.JointGrid(y='Br20 EqW',x='Br11 EqW', data=data1, size=10);
p = p.plot_joint(plt.scatter,s=5,color='black');
plt.ylim(-5,5)
p = p.plot_joint(sns.kdeplot,shade=True,shade_lowest=False,cmap='RdGy',zorder=0,n_levels=15)
p = p.plot_marginals(sns.distplot,kde=True)
plt.suptitle('Ones')

# %%
plt.figure(figsize=(13,10))
sns.distplot(br20eqw,bins=20,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'blue','alpha':.7})
plt.xlabel('Br20 EqW')
plt.title('Ones')

# %%
p = sns.JointGrid(y='Br20 EqW',x='Br11 EqW', data=data1, size=10);
p = p.plot_joint(plt.scatter,s=5,color='black');
p = p.plot_joint(sns.kdeplot,shade=True,shade_lowest=False,cmap='RdGy',zorder=0,n_levels=15)
p = p.plot_marginals(sns.distplot,kde=True)
plt.suptitle('Twos')

# %%
plt.figure(figsize=(13,10))
sns.distplot(br20eqw,bins=20,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'blue','alpha':.7})
plt.xlabel('Br20 EqW')
plt.title('Twos')

# %%
p = sns.JointGrid(y='Br20 EqW',x='Br11 EqW', data=data1, size=10);

p = p.plot_joint(plt.scatter,s=5,color='black');
plt.ylim(-2.5,7)
plt.xlim(-5,20)#there were a couple outliers but they were quite far away from the distibution
p = p.plot_joint(sns.kdeplot,shade=True,shade_lowest=False,cmap='RdGy',zorder=0,n_levels=15)

p = p.plot_marginals(sns.distplot,kde=True)
plt.suptitle('Threes')

# %%
plt.figure(figsize=(13,10))
sns.distplot(br20eqw,bins=20,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'blue','alpha':.7})
plt.xlim(-2.5,5.5)
plt.xlabel('Br20 EqW')
plt.title('Threes')

# %%
p = sns.JointGrid(y='Br20 EqW',x='Br11 EqW', data=data1, size=10);

p = p.plot_joint(plt.scatter,s=5,color='black');

p = p.plot_joint(sns.kdeplot,shade=True,shade_lowest=False,cmap='RdGy',zorder=0,n_levels=15)

p = p.plot_marginals(sns.distplot,kde=True)
plt.suptitle('Fours')

# %%
plt.figure(figsize=(13,10))
sns.distplot(br20eqw,bins=16,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'blue','alpha':.7})
plt.xlabel('Br20 EqW')
plt.title('Fours')
