# %%
# %run ../Modules/Importing.py

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Testing Area

# %%
lines = [16840.481,16802.368,16414.737,16388.492,16128.608,16079.753,15897.211,15890.033,15869.307,15862.489,
        15702.539,15597.631,15570.159,15546.141,15540.945,15539.711,15474.212,15462.125,15432.156,15430.163,15332.402,
        15287.789,15240.954,15187.140]
#x = f.apStar_to_apVisit(4586,'2M03434449+3143092')
#plateid = x[0][1][0]
#MJD = x[0][1][1]
#fiber = x[0][1][2]
plateid = 6218
MJD = 56172
fiber = '094'
emission_line = 11
f.Skyline_Plotter(plateid,MJD,fiber,emission_line)
for i in range(2):
    plt.axvline(lines[i],color = 'black',ls = 'dashdot')
plt.axvline(16839,color = 'black',ls = 'dashdot')
plt.axvline(16842,color = 'black',ls = 'dashdot')
f.Unshifted_Plotter(plateid,MJD,fiber,emission_line)
#plt.axvline(16414.75,color = 'black',ls = 'dashdot')
for i in range(2):
    plt.axvline(lines[i],color = 'black',ls = 'dashdot')
plt.axhline(522.5,color = 'black',ls = 'dashdot')
plt.axvline(16839,color = 'red')
plt.axvline(16842,color = 'red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-e5b5235b52e7> in <module>()
#      10 fiber = '094'
#      11 emission_line = 11
# ---> 12 f.Skyline_Plotter(plateid,MJD,fiber,emission_line)
#      13 for i in range(2):
#      14     plt.axvline(lines[i],color = 'black',ls = 'dashdot')
#
# /Users/ballanr/Desktop/SummerResearch/T-Tauri/Modules/functions.py in Skyline_Plotter(plateid, MJD, fiber, emission_line)
#     197
#     198     #Values for plotter needed-----------------------------------------------------------------------------------------------------------------------|
# --> 199     EqW,EqW_rounded,vbc,vhelio,Fluxcontinuum,centerline,shift = functions.Br_Equiv_Width(plateid,MJD,fiber,emission_line)
#     200
# ...

# %%
lines = [16840.481,16802.368,16414.737,16388.492,16128.608,16079.753,15897.211,15890.033,15869.307,15862.489,
        15702.539,15597.631,15570.159,15546.141,15540.945,15539.711,15474.212,15462.125,15432.156,15430.163,15332.402,
        15287.789,15240.954,15187.140]
#x = f.apStar_to_apVisit(4586,'2M03434449+3143092')
#plateid = x[0][1][0]
#MJD = x[0][1][1]
#fiber = x[0][1][2]
plateid = 6218
MJD = 56172
fiber = '094'
emission_line = 12
f.Skyline_Plotter(plateid,MJD,fiber,emission_line)
for i in range(2):
    plt.axvline(lines[i+2],color = 'black',ls = 'dashdot')
plt.axvline(16387,color = 'black',ls = 'dashdot')
plt.axvline(16390,color = 'black',ls = 'dashdot')
plt.axvline(16413.237,color = 'black',ls = 'dashdot')
plt.axvline(16416.237,color = 'black',ls = 'dashdot')
f.Unshifted_Plotter(plateid,MJD,fiber,emission_line)
#plt.axvline(16414.75,color = 'black',ls = 'dashdot')
for i in range(2):
    plt.axvline(lines[i+2],color = 'black',ls = 'dashdot')
#plt.axhline(522.5,color = 'black',ls = 'dashdot')
plt.axvline(16387,color = 'black',ls = 'dashdot')
plt.axvline(16390,color = 'black',ls = 'dashdot')
plt.axvline(16413.237,color = 'black',ls = 'dashdot')
plt.axvline(16416.237,color = 'black',ls = 'dashdot')
plt.show()

# %%
lines = [16840.481,16802.368,16414.737,16388.492,16128.608,16079.753,15897.211,15890.033,15869.307,15862.489,
        15702.539,15597.631,15570.159,15546.141,15540.945,15539.711,15474.212,15462.125,15432.156,15430.163,15332.402,
        15287.789,15240.954,15187.140]
#x = f.apStar_to_apVisit(4586,'2M03434449+3143092')
#plateid = x[0][1][0]
#MJD = x[0][1][1]
#fiber = x[0][1][2]
plateid = 6218
MJD = 56172
fiber = '094'
emission_line = 13
f.Skyline_Plotter(plateid,MJD,fiber,emission_line)
for i in range(2):
    plt.axvline(lines[i+4],color = 'black',ls = 'dashdot')
plt.axvline(16078.253,color = 'black',ls = 'dashdot')
plt.axvline(16081.253,color = 'black',ls = 'dashdot')
plt.axvline(16127.108,color = 'black',ls = 'dashdot')
plt.axvline(16130.108,color = 'black',ls = 'dashdot')
f.Unshifted_Plotter(plateid,MJD,fiber,emission_line)
#plt.axvline(16414.75,color = 'black',ls = 'dashdot')
for i in range(2):
    plt.axvline(lines[i+4],color = 'black',ls = 'dashdot')
#plt.axhline(522.5,color = 'black',ls = 'dashdot')
plt.axvline(16078.253,color = 'black',ls = 'dashdot')
plt.axvline(16081.253,color = 'black',ls = 'dashdot')
plt.axvline(16127.108,color = 'black',ls = 'dashdot')
plt.axvline(16130.108,color = 'black',ls = 'dashdot')
plt.show()

# %%
lines = [16840.481,16802.368,16414.737,16388.492,16128.608,16079.753,15897.211,15890.033,15869.307,15862.489,
        15702.539,15597.631,15570.159,15546.141,15540.945,15539.711,15474.212,15462.125,15432.156,15430.163,15332.402,
        15287.789,15240.954,15187.140]
#x = f.apStar_to_apVisit(4586,'2M03434449+3143092')
#plateid = x[0][1][0]
#MJD = x[0][1][1]
#fiber = x[0][1][2]
plateid = 6218
MJD = 56172
fiber = '094'
emission_line = 14
f.Skyline_Plotter(plateid,MJD,fiber,emission_line)
for i in range(4):
    plt.axvline(lines[i+6],color = 'black',ls = 'dashdot')
plt.axvline(15860.989,color = 'black',ls = 'dashdot')
plt.axvline(15863.989,color = 'black',ls = 'dashdot')
plt.axvline(15867.807,color = 'black',ls = 'dashdot')
plt.axvline(15870.807,color = 'black',ls = 'dashdot')
plt.axvline(15888.533,color = 'black',ls = 'dashdot')
plt.axvline(15891.533,color = 'black',ls = 'dashdot')
plt.axvline(15895.711,color = 'black',ls = 'dashdot')
plt.axvline(15898.711,color = 'black',ls = 'dashdot')
f.Unshifted_Plotter(plateid,MJD,fiber,emission_line)
#plt.axvline(16414.75,color = 'black',ls = 'dashdot')
for i in range(4):
    plt.axvline(lines[i+6],color = 'black',ls = 'dashdot')
#plt.axhline(522.5,color = 'black',ls = 'dashdot')
plt.axvline(15860.989,color = 'black',ls = 'dashdot')
plt.axvline(15863.989,color = 'black',ls = 'dashdot')
plt.axvline(15867.807,color = 'black',ls = 'dashdot')
plt.axvline(15870.807,color = 'black',ls = 'dashdot')
plt.axvline(15888.533,color = 'black',ls = 'dashdot')
plt.axvline(15891.533,color = 'black',ls = 'dashdot')
plt.axvline(15895.711,color = 'black',ls = 'dashdot')
plt.axvline(15898.711,color = 'black',ls = 'dashdot')
plt.show()

# %%
lines = [16840.481,16802.368,16414.737,16388.492,16128.608,16079.753,15897.211,15890.033,15869.307,15862.489,
        15702.539,15597.631,15570.159,15546.141,15540.945,15539.711,15474.212,15462.125,15432.156,15430.163,15332.402,
        15287.789,15240.954,15187.140]
#x = f.apStar_to_apVisit(4586,'2M03434449+3143092')
#plateid = x[0][1][0]
#MJD = x[0][1][1]
#fiber = x[0][1][2]
plateid = 6218
MJD = 56172
fiber = '094'
emission_line = 15
f.Skyline_Plotter(plateid,MJD,fiber,emission_line)
for i in range(1):
    plt.axvline(lines[i+10],color = 'black',ls = 'dashdot')
plt.axvline(15701.039,color = 'black',ls = 'dashdot')
plt.axvline(15704.039,color = 'black',ls = 'dashdot')

f.Unshifted_Plotter(plateid,MJD,fiber,emission_line)
#plt.axvline(16414.75,color = 'black',ls = 'dashdot')
for i in range(1):
    plt.axvline(lines[i+10],color = 'black',ls = 'dashdot')
#plt.axhline(522.5,color = 'black',ls = 'dashdot')
plt.axvline(15701.039,color = 'black',ls = 'dashdot')
plt.axvline(15704.039,color = 'black',ls = 'dashdot')

plt.show()

# %%
lines = [16840.481,16802.368,16414.737,16388.492,16128.608,16079.753,15897.211,15890.033,15869.307,15862.489,
        15702.539,15597.631,15570.159,15546.141,15540.945,15539.711,15474.212,15462.125,15432.156,15430.163,15332.402,
        15287.789,15240.954,15187.140]
#x = f.apStar_to_apVisit(4586,'2M03434449+3143092')
#plateid = x[0][1][0]
#MJD = x[0][1][1]
#fiber = x[0][1][2]
plateid = 6218
MJD = 56172
fiber = '094'
emission_line = 16
f.Skyline_Plotter(plateid,MJD,fiber,emission_line)
for i in range(5):
    plt.axvline(lines[i+11],color = 'black',ls = 'dashdot')
plt.axvline(15538.211,color = 'black',ls = 'dashdot')
plt.axvline(15541.211,color = 'black',ls = 'dashdot')
plt.axvline(15539.445,color = 'black',ls = 'dashdot')
plt.axvline(15542.445,color = 'black',ls = 'dashdot')
plt.axvline(15544.641,color = 'black',ls = 'dashdot')
plt.axvline(15547.641,color = 'black',ls = 'dashdot')
plt.axvline(15568.659,color = 'black',ls = 'dashdot')
plt.axvline(15571.659,color = 'black',ls = 'dashdot')
plt.axvline(15596.131,color = 'black',ls = 'dashdot')
plt.axvline(15599.131,color = 'black',ls = 'dashdot')

f.Unshifted_Plotter(plateid,MJD,fiber,emission_line)
#plt.axvline(16414.75,color = 'black',ls = 'dashdot')
for i in range(5):
    plt.axvline(lines[i+11],color = 'black',ls = 'dashdot')
#plt.axhline(522.5,color = 'black',ls = 'dashdot')
plt.axvline(15538.211,color = 'black',ls = 'dashdot')
plt.axvline(15541.211,color = 'black',ls = 'dashdot')
plt.axvline(15539.445,color = 'black',ls = 'dashdot')
plt.axvline(15542.445,color = 'black',ls = 'dashdot')
plt.axvline(15544.641,color = 'black',ls = 'dashdot')
plt.axvline(15547.641,color = 'black',ls = 'dashdot')
plt.axvline(15568.659,color = 'black',ls = 'dashdot')
plt.axvline(15571.659,color = 'black',ls = 'dashdot')
plt.axvline(15596.131,color = 'black',ls = 'dashdot')
plt.axvline(15599.131,color = 'black',ls = 'dashdot')

plt.show()

# %%
lines = [16840.481,16802.368,16414.737,16388.492,16128.608,16079.753,15897.211,15890.033,15869.307,15862.489,
        15702.539,15597.631,15570.159,15546.141,15540.945,15539.711,15474.212,15462.125,15432.156,15430.163,15332.402,
        15287.789,15240.954,15187.140]
#x = f.apStar_to_apVisit(4586,'2M03434449+3143092')
#plateid = x[0][1][0]
#MJD = x[0][1][1]
#fiber = x[0][1][2]
plateid = 6218
MJD = 56172
fiber = '094'
emission_line = 17
f.Skyline_Plotter(plateid,MJD,fiber,emission_line)
for i in range(4):
    plt.axvline(lines[i+16],color = 'black',ls = 'dashdot')
plt.axvline(15429.663,color = 'black',ls = 'dashdot')
plt.axvline(15432.663,color = 'black',ls = 'dashdot')
plt.axvline(15430.656,color = 'black',ls = 'dashdot')
plt.axvline(15433.656,color = 'black',ls = 'dashdot')
plt.axvline(15460.525,color = 'black',ls = 'dashdot')
plt.axvline(15463.525,color = 'black',ls = 'dashdot')
plt.axvline(15472.712,color = 'black',ls = 'dashdot')
plt.axvline(15475.712,color = 'black',ls = 'dashdot')


f.Unshifted_Plotter(plateid,MJD,fiber,emission_line)
#plt.axvline(16414.75,color = 'black',ls = 'dashdot')
for i in range(4):
    plt.axvline(lines[i+16],color = 'black',ls = 'dashdot')
#plt.axhline(522.5,color = 'black',ls = 'dashdot')
plt.axvline(15429.663,color = 'black',ls = 'dashdot')
plt.axvline(15432.663,color = 'black',ls = 'dashdot')
plt.axvline(15430.656,color = 'black',ls = 'dashdot')
plt.axvline(15433.656,color = 'black',ls = 'dashdot')
plt.axvline(15460.525,color = 'black',ls = 'dashdot')
plt.axvline(15463.525,color = 'black',ls = 'dashdot')
plt.axvline(15472.712,color = 'black',ls = 'dashdot')
plt.axvline(15475.712,color = 'black',ls = 'dashdot')


plt.show()

# %%
lines = [16840.481,16802.368,16414.737,16388.492,16128.608,16079.753,15897.211,15890.033,15869.307,15862.489,
        15702.539,15597.631,15570.159,15546.141,15540.945,15539.711,15474.212,15462.125,15432.156,15430.163,15332.402,
        15287.789,15240.954,15187.140]
#x = f.apStar_to_apVisit(4586,'2M03434449+3143092')
#plateid = x[0][1][0]
#MJD = x[0][1][1]
#fiber = x[0][1][2]
plateid = 6218
MJD = 56172
fiber = '094'
emission_line = 18
f.Skyline_Plotter(plateid,MJD,fiber,emission_line)
for i in range(1):
    plt.axvline(lines[i+20],color = 'black',ls = 'dashdot')
plt.axvline(15330.902,color = 'black',ls = 'dashdot')
plt.axvline(15333.902,color = 'black',ls = 'dashdot')


f.Unshifted_Plotter(plateid,MJD,fiber,emission_line)
#plt.axvline(16414.75,color = 'black',ls = 'dashdot')
for i in range(1):
    plt.axvline(lines[i+20],color = 'black',ls = 'dashdot')
#plt.axhline(522.5,color = 'black',ls = 'dashdot')
plt.axvline(15330.902,color = 'black',ls = 'dashdot')
plt.axvline(15333.902,color = 'black',ls = 'dashdot')

plt.show()

# %%
lines = [16840.481,16802.368,16414.737,16388.492,16128.608,16079.753,15897.211,15890.033,15869.307,15862.489,
        15702.539,15597.631,15570.159,15546.141,15540.945,15539.711,15474.212,15462.125,15432.156,15430.163,15332.402,
        15287.789,15240.954,15187.140]
#x = f.apStar_to_apVisit(4586,'2M03434449+3143092')
#plateid = x[0][1][0]
#MJD = x[0][1][1]
#fiber = x[0][1][2]
plateid = 6218
MJD = 56172
fiber = '094'
emission_line = 19
f.Skyline_Plotter(plateid,MJD,fiber,emission_line)
for i in range(2):
    plt.axvline(lines[i+21],color = 'black',ls = 'dashdot')
plt.axvline(15239.454,color = 'black',ls = 'dashdot')
plt.axvline(15242.454,color = 'black',ls = 'dashdot')
plt.axvline(15286.289,color = 'black',ls = 'dashdot')
plt.axvline(15289.289,color = 'black',ls = 'dashdot')


f.Unshifted_Plotter(plateid,MJD,fiber,emission_line)
#plt.axvline(16414.75,color = 'black',ls = 'dashdot')
for i in range(2):
    plt.axvline(lines[i+21],color = 'black',ls = 'dashdot')
#plt.axhline(522.5,color = 'black',ls = 'dashdot')
plt.axvline(15239.454,color = 'black',ls = 'dashdot')
plt.axvline(15242.454,color = 'black',ls = 'dashdot')
plt.axvline(15286.289,color = 'black',ls = 'dashdot')
plt.axvline(15289.289,color = 'black',ls = 'dashdot')

plt.show()

# %%
lines = [16840.481,16802.368,16414.737,16388.492,16128.608,16079.753,15897.211,15890.033,15869.307,15862.489,
        15702.539,15597.631,15570.159,15546.141,15540.945,15539.711,15474.212,15462.125,15432.156,15430.163,15332.402,
        15287.789,15240.954,15187.140]
#x = f.apStar_to_apVisit(4586,'2M03434449+3143092')
#plateid = x[0][1][0]
#MJD = x[0][1][1]
#fiber = x[0][1][2]
plateid = 6218
MJD = 56172
fiber = '094'
emission_line = 20
f.Skyline_Plotter(plateid,MJD,fiber,emission_line)
for i in range(1):
    plt.axvline(lines[i+23],color = 'black',ls = 'dashdot')
plt.axvline(15185.640,color = 'black',ls = 'dashdot')
plt.axvline(15188.640,color = 'black',ls = 'dashdot')
f.Unshifted_Plotter(plateid,MJD,fiber,emission_line)
#plt.axvline(16414.75,color = 'black',ls = 'dashdot')
for i in range(1):
    plt.axvline(lines[i+23],color = 'black',ls = 'dashdot')
#plt.axhline(522.5,color = 'black',ls = 'dashdot')
plt.axvline(15185.640,color = 'black',ls = 'dashdot')
plt.axvline(15188.640,color = 'black',ls = 'dashdot')
plt.show()

# %% [markdown]
# | Brackett Line | Fc/Peak    | Cutoff   | Cutoff to Fc/Peak |
# |:--------:|:------------------:|:--------:|:---:|
# |11|0.53|0.61|1.151
# |12|0.56|0.67|1.196
# |13|0.64|0.72|1.125
# |14|0.65|0.71|1.092
# |15|0.675|0.72|1.067
# |16|0.707|0.76|1.075
# |17|0.73|0.8|1.096
# |18|0.77|0.85|1.104
# |19|0.766|0.83|1.084
# |20|0.8|0.885|1.106

# %% [markdown]
# | Brackett Line | OH Line | $\Delta\lambda$    | velocity   |
# |:--------:|:------------------:|:--------:||:--------:|
# |11|1|-29.302|-522.540|
# |  |2|8.811|157.126|
# |12|3|-2.997|-54.746|
# |  |4|23.248|424.67|
# |13|5|-14.380|-275.908|
# |  |6|34.025|633.026|
# |14|7|-12.267|-231.512|
# |  |8|-5.089|-96.043|
# |  |9|15.637|295.113|
# |  |10|22.455|423.787|
# |15|11|2.476|47.264|
# |16|12|-36.870|-710.335|
# |  |13|-9.398|-181.061|
# |  |14|14.620|281.668|
# |  |15|19.816|381.774|
# |  |16|21.050|405.548|
# |17|17|-31.012|-602.023|
# |  |18|-18.925|-367.383|
# |  |19|11.044|214.393|
# |  |20|13.037|253.082|
# |18|21|13.641|266.484|
# |19|22|-23.021|-452.121|
# |  |23|23.814|467.695|
# |20|24|8.916|175.898|
