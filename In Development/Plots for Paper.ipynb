# %% [markdown]
# # Plot Recreations

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import itertools
from astropy.io import fits
# %matplotlib inline

# %%
# %run ../Modules/Importing.py

# %% [markdown]
# ### First Cut

# %%
filepath = '/Users/ballanr/Desktop/Confidence Plots/Confidence.csv'
openfile = pd.read_csv(filepath)

# %%
zeros = []
ones = []
for index,row in itertools.islice(openfile.iterrows(),0,None):
    if row['Emitter'] == 1:
        ones.append(row['Overall Confidence'])
    else:
        zeros.append(row['Overall Confidence'])

# %%
len(zeros),len(ones)
# Out:
# (868, 15)

# %%
plt.figure(figsize=(20,10));
plt.hist(zeros,normed=True,alpha=0.5);
plt.hist(ones,normed=True,alpha=0.5);
plt.xlim(-2.5,5)
# Out:
# (-2.5, 5)

# %%
plt.figure(figsize=(20,10))
sns.distplot(zeros,bins=20,kde=False,norm_hist=True,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'blue','alpha':.7})
sns.distplot(ones,bins=20,kde=False,norm_hist=True,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'red','alpha':.7})
#plt.xlim(-5,5)

# %% [markdown]
# ### Second Cut

# %%
filepath = '/Users/ballanr/Desktop/Confidence Plots/Confidence2.csv'
openfile = pd.read_csv(filepath)

# %%
zeros = []
ones = []
for index,row in itertools.islice(openfile.iterrows(),0,None):
    if row['Emitter'] == 1:
        ones.append(row['Confidence'])
    else:
        zeros.append(row['Confidence'])

# %%
plt.figure(figsize=(13,10))
binBoundaries = np.linspace(1,20,77)
sns.distplot(zeros,bins=binBoundaries,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'solid','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'blue','alpha':.7},label='Non-emitters')
sns.distplot(ones,bins=binBoundaries,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'red','alpha':.7},label='Emitters')
plt.xlim(1,5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Confidence Score',fontsize=24)
plt.legend(fontsize=22)
plt.savefig('/Users/ballanr/Desktop/Confidence Plots/Confidence Histogram.pdf',bbox_inches='tight',dpi=300)

# %%
orion_A = [7220,7221,7222,7223,7224,7225,7226,7227,7228,7229,7230,7231,7232,7233,7234,9659,9660,9661]
lam_ori = [8879,8880,8881,8882,8883,8884,8885,8886,9482]
orion_B = [8890,8891,8892,8893,8894,8895,8896,8897,8898,8899]
orion_OB1AB = [8900,8901,8902,8903,8904,8905,8906,9468,9469,9470,9471,9472,9473,9474,9475,9476,9477]
taurus = [9258,9259,9287,9288]
perseus = [9662]
IC348 = [6218,6219,6220,6221,6222,6223,7073,7074,7075,7079]
NGC1333 = [6224,6225,6226,7070,7071,7072]

# %%
ori0 = []
tau0 = []
pers0 = []
ori1 = []
tau1 = []
pers1 = []
ones = []
zeros = []

for index,row in itertools.islice(openfile.iterrows(),0,None):
    if row['Emitter'] == 1:
        
        if row['Plate'] in orion_A:
            ori1.append(row['Confidence'])
            ones.append(row['Confidence'])
        elif row['Plate'] in lam_ori:
            ori1.append(row['Confidence'])
            ones.append(row['Confidence'])
        elif row['Plate'] in orion_B:
            ori1.append(row['Confidence'])
            ones.append(row['Confidence'])
        elif row['Plate'] in orion_OB1AB:
            ori1.append(row['Confidence'])
            ones.append(row['Confidence'])
        elif row['Plate'] in taurus:
            tau1.append(row['Confidence'])
            ones.append(row['Confidence'])
        elif row['Plate'] in perseus:
            pers1.append(row['Confidence'])
            ones.append(row['Confidence'])
        elif row['Plate'] in IC348:
            pers1.append(row['Confidence'])
            ones.append(row['Confidence'])
        elif row['Plate'] in NGC1333:
            pers1.append(row['Confidence'])
            ones.append(row['Confidence'])
        
    else:
        
        if row['Plate'] in orion_A:
            ori0.append(row['Confidence'])
            zeros.append(row['Confidence'])
        elif row['Plate'] in lam_ori:
            ori0.append(row['Confidence'])
            zeros.append(row['Confidence'])
        elif row['Plate'] in orion_B:
            ori0.append(row['Confidence'])
            zeros.append(row['Confidence'])
        elif row['Plate'] in orion_OB1AB:
            ori0.append(row['Confidence'])
            zeros.append(row['Confidence'])
        elif row['Plate'] in taurus:
            tau0.append(row['Confidence'])
            zeros.append(row['Confidence'])
        elif row['Plate'] in perseus:
            pers0.append(row['Confidence'])
            zeros.append(row['Confidence'])
        elif row['Plate'] in IC348:
            pers0.append(row['Confidence'])
            zeros.append(row['Confidence'])
        elif row['Plate'] in NGC1333:
            pers0.append(row['Confidence'])
            zeros.append(row['Confidence'])

# %%
len(ori0),len(ori1)
# Out:
# (140, 354)

# %%
len(tau0),len(tau1)
# Out:
# (21, 13)

# %%
len(pers0),len(pers1)
# Out:
# (66, 23)

# %%
len(zeros),len(ones)
# Out:
# (227, 390)

# %%
plt.figure(figsize=(13,10))
binBoundaries = np.linspace(1,15,57)

sns.distplot(ori0,bins=binBoundaries,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'solid','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'blue','alpha':.7},label='Non-emitters')
sns.distplot(ori1,bins=binBoundaries,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'red','alpha':.7},label='Emitters')
plt.xlim(1,5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Confidence Score',fontsize=22)
plt.legend(fontsize=22)
plt.title('Orion',fontsize=24)
plt.savefig('/Users/ballanr/Desktop/Confidence Plots/Orion Histogram.pdf',bbox_inches='tight',dpi=300)

# %%
plt.figure(figsize=(13,10))
binBoundaries = np.linspace(1,15,57)

sns.distplot(tau0,bins=binBoundaries,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'solid','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'blue','alpha':.7},label='Non-emitters')
sns.distplot(tau1,bins=binBoundaries,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'red','alpha':.7},label='Emitters')
plt.xlim(1,5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Confidence Score',fontsize=22)
plt.legend(fontsize=22)
plt.title('Taurus',fontsize=24)
plt.savefig('/Users/ballanr/Desktop/Confidence Plots/Taurus Histogram.pdf',bbox_inches='tight',dpi=300)

# %%
plt.figure(figsize=(13,10))
binBoundaries = np.linspace(1,15,57)

sns.distplot(pers0,bins=binBoundaries,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'solid','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'blue','alpha':.7},label='Non-emitters')
sns.distplot(pers1,bins=binBoundaries,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'red','alpha':.7},label='Emitters')
plt.xlim(1,5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Confidence Score',fontsize=22)
plt.legend(fontsize=22)
plt.title('Perseus',fontsize=24)
plt.savefig('/Users/ballanr/Desktop/Confidence Plots/Perseus Histogram.pdf',bbox_inches='tight',dpi=300)

# %%
plt.figure(figsize=(13,10))
binBoundaries = np.linspace(1,15,57)

sns.distplot(zeros,bins=binBoundaries,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'solid','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'blue','alpha':.7},label='Non-emitters')
sns.distplot(ones,bins=binBoundaries,kde=False,norm_hist=False,kde_kws={'color':'black','ls':'dashed','lw':2},
            hist_kws={'edgecolor':'black','linewidth':1,'color':'red','alpha':.7},label='Emitters')
plt.xlim(1,5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Confidence Score',fontsize=22)
plt.legend(fontsize=22)
plt.title('Orion/Perseus/Taurus',fontsize=24)
plt.savefig('/Users/ballanr/Desktop/Confidence Plots/OPT Histogram.pdf',bbox_inches='tight',dpi=300)

# %%
between = []

sample = len(tau1)
for i in range(len(tau1)):
    
    if tau1[i] > 1 and tau1[i] < 2.5:
        
        between.append(tau1[i])

sample,len(between),sample-len(between)
# Out:
# (13, 1, 12)

# %% [markdown]
# ## Plotting Spectra

# %% [markdown]
# ### Strong

# %%
plate = '6223'
mjd = '56282'
fiber = '099'

server = '/Users/ballanr/Desktop/File Outputs/DR15/Wave and Flux/'
filepath = plate+'-'+mjd+'-'+fiber+'.csv'

path = server + filepath

# %%
openfile = pd.read_csv(path)
wave = openfile['Wavelength']
flux = openfile['Flux']

# %%
plt.figure(figsize=(13,10))
plt.scatter(wave,flux,s=.25)
#plt.xlim(16770,16850)
plt.xlabel('Wavelength',fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylabel('Flux',fontsize=18)
plt.title('2M03434449+3143092',fontsize=18)
plt.savefig('/Users/ballanr/Desktop/File Outputs/Paper/2M03434449+3143092 Updated Spectra.pdf',bbox_inches='tight',dpi=300)

# %%
plt.figure(figsize=(13,10))
plt.plot(wave,flux)
plt.fill_between((16783.58,16793.79),0,1400,color='green',alpha=0.2)
plt.fill_between((16828.21, 16838.42),0,1400,color='green',alpha=0.2)
plt.fill_between((16805.311, 16816.689),0,590,color='blue',alpha=0.2)
plt.xlim(16770,16850)
plt.ylim(200,1400)
plt.axvline(16811,ls='dashed',color='red')
plt.axhline(590,ls='dashed',color='k')
plt.xlabel('Wavelength',fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylabel('Flux',fontsize=18)
plt.title('2M03434449+3143092',fontsize=18)
plt.savefig('/Users/ballanr/Desktop/File Outputs/Paper/Strong Br11 Example.pdf',bbox_inches='tight',dpi=300)

# %% [markdown]
# ### Weak

# %%
plate2 = '6103'
mjd2 = '56204'
fiber2 = '105'

server2 = '/Users/ballanr/Desktop/File Outputs/DR15/Wave and Flux/'
filepath2 = plate2+'-'+mjd2+'-'+fiber2+'.csv'

path2 = server2 + filepath2

openfile2 = pd.read_csv(path2)
wave2 = openfile2['Wavelength']
flux2 = openfile2['Flux']

# %%
plt.figure(figsize=(13,10))
plt.plot(wave2,flux2)
plt.fill_between((16783.58,16793.79),0,1400,color='green',alpha=0.2)
plt.fill_between((16828.21, 16838.42),0,1400,color='green',alpha=0.2)
plt.fill_between((16809.916437596, 16812.083562404),0,250,color='blue',alpha=0.2)
plt.xlim(16770,16850)
plt.ylim(100,500)
plt.axvline(16811,ls='dashed',color='red')
plt.axhline(250,ls='dashed',color='k')
plt.xlabel('Wavelength',fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylabel('Flux',fontsize=18)
plt.title('2M06405926+0933250',fontsize=18)
plt.savefig('/Users/ballanr/Desktop/File Outputs/Paper/Weak Br11 Example.pdf',bbox_inches='tight',dpi=300)

# %% [markdown]
# ## Fitting
