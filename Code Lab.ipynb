# %% [markdown]
# # Test out Code here

# %%
import apogee.tools.read as apread
import apogee.spec.plot as splot
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
# %matplotlib inline
Lambda = splot.apStarWavegrid()

# %%
#Read in APOGEE Spectrum
#visit1 = 1
#spec10= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit1]
#spec11= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[2 + visit1]
#spec12= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[4 + visit1]
#spec13= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[8 + visit1]
#spec14= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[16 + visit1]
#spec2= apread.apStar(4587,'2M03250943+3046215',ext=1,header=False)[1 + visit1]
#spec3= apread.apStar(4587,'2M03292187+3115363',ext=1,header=False)[1 + visit1]
#spec4= apread.apStar(4587,'2M03295403+3120529',ext=1,header=False)[1 + visit1]
#spec5= apread.apStar(4572,'2M06413876+0932117',ext=1,header=False)[1 + visit1]
#spec6= apread.apStar(4572,'2M06410890+0929451',ext=1,header=False)[1 + visit1]
#spec7= apread.apStar(4572,'2M06410715+0927294',ext=1,header=False)[1 + visit1]
#spec8= apread.apStar(4572,'2M06405926+0933250',ext=1,header=False)[1 + visit1]
#spec9= apread.apStar(4572,'2M06405639+0935533',ext=1,header=False)[1 + visit1]
#spec20= apread.apStar(4572,'2M06405426+0949203',ext=1,header=False)[1 + visit1]
#spec21= apread.apStar(4572,'2M06404837+0948385',ext=1,header=False)[1 + visit1]

# %%
def find_nearest(array,value):
    idx = (np.abs(array-value)).argmin()
    #return array[idx]
    return idx

# %% [markdown]
# ### Finding Median Values for our Graphs

# %%
#spec101= apread.apStar(4586,'2M03434449+3143092',ext=0,header=True)
#spec102= apread.apStar(4587,'2M03250943+3046215',ext=0,header=True)
#spec103= apread.apStar(4587,'2M03292187+3115363',ext=0,header=True)
#spec104= apread.apStar(4587,'2M03295403+3120529',ext=0,header=True)
#spec105= apread.apStar(4572,'2M06413876+0932117',ext=0,header=True)
#spec106= apread.apStar(4572,'2M06410890+0929451',ext=0,header=True)
#spec107= apread.apStar(4572,'2M06410715+0927294',ext=0,header=True)
#spec108= apread.apStar(4572,'2M06405926+0933250',ext=0,header=True)
spec109= apread.apStar(4572,'2M06405639+0935533',ext=0,header=True)
#spec110= apread.apStar(4572,'2M06405426+0949203',ext=0,header=True)
#spec111= apread.apStar(4572,'2M06404837+0948385',ext=0,header=True)
#print spec101[1]['NVISITS']
#print spec102[1]['NVISITS']
#print spec103[1]['NVISITS']
#print spec104[1]['NVISITS']
#print spec105[1]['NVISITS']
#print spec106[1]['NVISITS']
#print spec107[1]['NVISITS']
#print spec108[1]['NVISITS']
print range(spec109[1]['NVISITS'])
#print spec110[1]['NVISITS']
#print spec111[1]['NVISITS']
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
#let's try graphing all 6 visits from an easy to 
#read spec like spec109

# %%
visit1 = 1
spec21= apread.apStar(4587,'2M03250943+3046215',ext=1,header=False)[1 + visit1]
fig = plt.figure()
plt.plot(Lambda,spec21)
fig.suptitle('Visit #1', fontsize=20)
plt.axvline(x=16810.7776,ls='dashed',color='r')
plt.xlim([16770,16850])
plt.ylim([450,700])
# Out:
# (450, 700)

# %% [markdown]
# ## Visit 2

# %%
visit1 = 2
spec22= apread.apStar(4587,'2M03250943+3046215',ext=1,header=False)[1 + visit1]
fig = plt.figure()
plt.plot(Lambda,spec22)
fig.suptitle('Visit #2', fontsize=20)
plt.axvline(x=16810.7776,ls='dashed',color='r')
plt.xlim([16770,16850])
plt.ylim([450,800])
# Out:
# (450, 800)

# %% [markdown]
# ## Visit 3

# %%
visit1 = 3
spec23= apread.apStar(4587,'2M03250943+3046215',ext=1,header=False)[1 + visit1]
fig = plt.figure()
plt.plot(Lambda,spec23)
fig.suptitle('Visit #3', fontsize=20)
plt.axvline(x=16810.7776,ls='dashed',color='r')
plt.xlim([16770,16850])
plt.ylim([450,800])
# Out:
# (450, 800)

# %% [markdown]
# ## Visit 4

# %%
visit1 = 4
spec24= apread.apStar(4587,'2M03250943+3046215',ext=1,header=False)[1 + visit1]
fig = plt.figure()
plt.plot(Lambda,spec24)
fig.suptitle('Visit #4', fontsize=20)
plt.axvline(x=16810.7776,ls='dashed',color='r')
#plt.axvline(x=Lambda[7695],ls='dashed',color='black')
#plt.axvline(x=Lambda[7660],ls='dashed',color='black')
#plt.axvline(x=Lambda[7835],ls='dashed',color='black')
#plt.axvline(x=Lambda[7870],ls='dashed',color='black')
plt.xlim([16770,16850])
plt.ylim([450,800])
# Out:
# (450, 800)

# %% [markdown]
# ## Visit 5

# %%
visit1 = 5
spec25= apread.apStar(4587,'2M03250943+3046215',ext=1,header=False)[1 + visit1]
fig = plt.figure()
plt.plot(Lambda,spec25)
fig.suptitle('Visit #5', fontsize=20)
plt.axvline(x=16810.7776,ls='dashed',color='r')
#plt.axvline(x=Lambda[7695],ls='dashed',color='black')
#plt.axvline(x=Lambda[7660],ls='dashed',color='black')
#plt.axvline(x=Lambda[7835],ls='dashed',color='black')
#plt.axvline(x=Lambda[7870],ls='dashed',color='black')
plt.xlim([16770,16850])
plt.ylim([450,800])
# Out:
# (450, 800)

# %% [markdown]
# ## Visit 6

# %%
visit1 = 6
spec26= apread.apStar(4587,'2M03250943+3046215',ext=1,header=False)[1 + visit1]
fig = plt.figure()
plt.plot(Lambda,spec26)
fig.suptitle('Visit #6', fontsize=20)
#plt.axvline(x=16810.7776,ls='dashed',color='black')
plt.axvline(x=Lambda[7765],ls='solid',color='r')
#plt.axvline(x=Lambda[7695],ls='dashed',color='black')
#plt.axvline(x=Lambda[7660],ls='dashed',color='black')
#plt.axvline(x=Lambda[7835],ls='dashed',color='black')
#plt.axvline(x=Lambda[7870],ls='dashed',color='black')
plt.xlim([16770,16850])
plt.ylim([450,800])
# Out:
# (450, 800)

# %% [markdown]
# ## Visit 7

# %%
visit1 = 7
spec27= apread.apStar(4587,'2M03250943+3046215',ext=1,header=False)[1 + visit1]
fig = plt.figure()
plt.plot(Lambda,spec27)
fig.suptitle('Visit #7', fontsize=20)
#plt.axvline(x=16810.7776,ls='dashed',color='black')
plt.axvline(x=Lambda[7765],ls='solid',color='r')
plt.axvline(x=Lambda[7810],ls='dashed',color='black')
plt.axvline(x=Lambda[7720],ls='dashed',color='black')
plt.axvline(x=Lambda[7855],ls='dashed',color='black')
plt.axvline(x=Lambda[7675],ls='dashed',color='black')
plt.xlim([16770,16850])
plt.ylim([450,800])
# Out:
# (450, 800)

# %% [markdown]
# # EqW Function

# %%
def Equiv_Width(plate_number,twomass_id,calculated_point):
    
    #given a certain spec
    spec_header = apread.apStar(plate_number,twomass_id,ext=0,header=True)
    nvisits = spec_header[1]['NVISITS']
    EqW_array = []
    for i in range(nvisits):
        spec = apread.apStar(plate_number,twomass_id,ext=1,header=False)[2 + i]
    
    
        centerline = find_nearest(Lambda,calculated_point)
        L1 = centerline - 90
        L2 = centerline - 45
        R1 = centerline + 45
        R2 = centerline + 90
        #generic continuum lines 35 elements wide 
        lsum= np.sum(spec[L1:L2])/ len(spec[L1:L2])
        rsum = np.sum(spec[R1:R2])/len(spec[R1:R2])
        Fc= (lsum+rsum)/2
    
        EqW=0
        
        for i in range(L2,R1):
            summ=(Fc*(Lambda[i+1]-Lambda[i]))-((1./2.)*(Lambda[i+1]-Lambda[i])*(spec[i+1]+spec[i]))
            EqW = EqW + summ
        EqW = abs(EqW/Fc)
        EqW_array.append(EqW)
        

    STD = np.std(EqW_array)
    
    EqW_M = np.median(EqW_array)
    
    #print np.sort(EqW_array)
    print 'The Equivalent Width is',EqW_M,'.'
    print 'The Standard Deviation is',STD,'.'

# %%
Equiv_Width(4572,'2M06405639+0935533',16810.7776)
# Out:
# The Equivalent Width is 3.62092019299 .
# The Standard Deviation is 0.610078664512 .

# %% [markdown]
# ## Spec 1 EqW

# %%
Equiv_Width(4586,'2M03434449+3143092',16785.024)
# Out:
# The Equivalent Width is 7.96822859713 .
# The Standard Deviation is 2.25293110406 .

# %% [markdown]
# ## Spec 2 EqW

# %%
Equiv_Width(4587,'2M03250943+3046215',16810.7776)
# Out:
# The Equivalent Width is 2.0868311694 .
# The Standard Deviation is 0.645998907527 .

# %% [markdown]
# ## Spec 3 EqW

# %%
Equiv_Width(4587,'2M03292187+3115363',16810.810)
# Out:
# The Equivalent Width is 0.866698314346 .
# The Standard Deviation is 0.344787012318 .

# %% [markdown]
# ## Spec 4 EqW

# %%
Equiv_Width(4587,'2M03295403+3120529',16810.91986)
# Out:
# The Equivalent Width is 1.15335205552 .
# The Standard Deviation is 0.218292614036 .

# %% [markdown]
# ## Spec 5 EqW

# %%
Equiv_Width(4572,'2M06413876+0932117',16810.724)
# Out:
# The Equivalent Width is 1.91279829121 .
# The Standard Deviation is 0.366134156239 .

# %% [markdown]
# ## Spec 6 EqW

# %%
Equiv_Width(4572,'2M06410890+0929451',16778.9039)
# Out:
# The Equivalent Width is 3.21538377215 .
# The Standard Deviation is 0.551790021425 .

# %% [markdown]
# ## Spec 7 EqW

# %%
Equiv_Width(4572,'2M06410715+0927294',16810.5)
# Out:
# The Equivalent Width is 0.230100341966 .
# The Standard Deviation is 0.681202034006 .

# %% [markdown]
# ## Spec 8 EqW

# %%
Equiv_Width(4572,'2M06405926+0933250',16810.487)
# Out:
# The Equivalent Width is 2.04592467898 .
# The Standard Deviation is 0.170003389972 .

# %% [markdown]
# ## Spec 9 EqW

# %%
Equiv_Width(4572,'2M06405639+0935533',16810.361)
# Out:
# The Equivalent Width is 3.69921034097 .
# The Standard Deviation is 0.616697019926 .

# %% [markdown]
# ## Spec 10 EqW

# %%
Equiv_Width(4572,'2M06405426+0949203',16810.361)
# Out:
# The Equivalent Width is 0.863757709636 .
# The Standard Deviation is 0.35128815069 .
