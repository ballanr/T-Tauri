# %% [markdown]
# # 2M03434449+3143092 Spectra Import

# %%
import apogee.tools.read as apread
from apogee.tools import bitmask
import apogee.spec.plot as splot
import numpy as np
import matplotlib.pyplot as plt

# %%
#Just testing out importing multiple visits and plotting them in pyplot

visit1 = 1
spec1= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit1]
visit2 = 2
spec2= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit2]
visit3 = 3
spec3= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit3]
visit4 = 4
spec4= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit4]

visit5 = 1
spec5= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit5]
visit6 = 6
spec6= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit6]
visit7 = 7
spec7= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit7]
visit8 = 8
spec8= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit8]

visit9 = 9
spec9= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit9]
visit10 = 10
spec10= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit10]
visit11 = 11
spec11= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit11]
visit12 = 12
spec12= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit12]

visit13 = 13
spec13= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit13]
visit14 = 14
spec14= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit14]
visit15 = 15
spec15= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit15]
visit16 = 16
spec16= apread.apStar(4586,'2M03434449+3143092',ext=1,header=False)[1 + visit16]

# %%
fig = plt.figure()
plt.plot(spec1)
plt.plot(spec2)
plt.plot(spec3)
plt.plot(spec4)
plt.plot(spec5)
plt.plot(spec6)
plt.plot(spec7)
plt.plot(spec8)
plt.plot(spec9)
plt.plot(spec10)
plt.plot(spec11)
plt.plot(spec12)
plt.plot(spec13)
plt.plot(spec14)
plt.plot(spec15)
plt.plot(spec16)


fig.suptitle('Test', fontsize=20)
plt.xlabel('Indices', fontsize=18)
plt.ylabel('FLUX', fontsize=16)
plt.xlim([3000,6000])
plt.ylim([0,4000])
# Out:
# (0, 4000)

# %%
#now plotting with the apogee package and zooming in on the Br11 line

splot.waveregions(spec1,apStar=True, startlams=[16700],endlams=[16900],
                  labelID='2M03434449+3143092')
splot.waveregions(spec1,apStar=True, startlams=[16760],endlams=[16805],
                  labelID='2M03434449+3143092')
splot.waveregions(spec2,apStar=True, startlams=[16700],endlams=[16900],
                  labelID='2M03434449+3143092')

# %%
#whole spectra with different color detectors using the apogee package

splot.detector(4586,'2M03434449+3143092','blue',ext=1,labelLines=False,
               labelID='2M03434449+3143092')
splot.detector(4586,'2M03434449+3143092','green',ext=1,labelLines=False,
               labelID='2M03434449+3143092')
splot.detector(4586,'2M03434449+3143092','red',ext=1,labelLines=False,
               labelID='2M03434449+3143092')
